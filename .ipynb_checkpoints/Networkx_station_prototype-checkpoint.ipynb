# %%
import pandas as pd
import numpy as np
import networkx as nx

#Visualizations
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap as Basemap

# from nxviz import CircosPlot # Needs to be installed

# %% [raw]
# S = nx.Graph()

# %%
# using 2010 data for graphing, smallest data set to build the prototype for using NetworkX faster
year = 2017
station_csv = pd.read_csv("~/Projects/NiceRide/Nice_Ride_data/"+str(year)+"/NiceRide_station_"+str(year)+".csv")
ride_csv = pd.read_csv("~/Projects/NiceRide/Nice_Ride_data/"+str(year)+"/NiceRide_trip_history_"+str(year)+".csv")

# %%
station_df = pd.DataFrame(station_csv)
rides_df = pd.DataFrame(ride_csv)

# %%
rides_df.head()
# Out:
#             Start_date                        Start_name  Start_id  \
# 0  2017-11-05 21:45:00   Hennepin Ave & S Washington Ave     30184
# 1  2017-11-05 21:45:00  Broadway Street N & 4th Street E     30122
# 2  2017-11-05 21:43:00          Dale Street & Grand Ave.     30106
# 3  2017-11-05 21:41:00                Weisman Art Museum     30183
# 4  2017-11-05 21:38:00      South 2nd Street & 3rd Ave S     30030
#
#               End_date                          End_name  End_id  duration  \
# 0  2017-11-05 22:02:00                        Logan Park   30104      1048
# 1  2017-11-05 22:26:00  Broadway Street N & 4th Street E   30122      2513
# 2  2017-11-05 22:13:00      N Milton Street & Summit Ave   30101      1817
# 3  2017-11-05 22:05:00         22nd Ave S & Franklin Ave   30014      1399
# 4  2017-11-05 21:44:00       6th Ave SE & University Ave   30088       370
#
#   account
# 0  Member
# 1  Member
# 2  Member
# 3  Casual
# 4  Member

# %%
# Data clean this out =/
if year == 2012 :
    rides_df = rides_df[rides_df.End_id != 30157]
    rides_df = rides_df[rides_df.End_id != 30160]

# %%
# returns a dataframe with the total sum of duration from station start and station end
duration_sum = rides_df.groupby(by=['Start_id', 'End_id'],axis=0, as_index=False).sum()

# %%
# returns a dataframe with the total count of rides from station start and station end
ride_counts = rides_df.drop(['Start_date', 'Start_name', 'End_date', 'End_name', 'duration', 'account'], axis=1)
ride_counts['counts'] = 0
ride_counts = ride_counts.groupby(by=['Start_id', 'End_id'],axis=0, as_index=False)['counts'].count()

# %% [raw]
# ride_counts_duration = pd.merge(duration_sum, ride_counts)
#
# merge prototype

# %%
def normalize(v):
    norm = np.linalg.norm(v)
    if norm == 0: 
       return v
    return v / norm

# %%
ride_counts['norm_counts'] = normalize(ride_counts['counts'].values)

# %%
ride_counts.norm_counts.max()
# Out:
# 0.42338889834476878

# %% [raw]
# dcs = nx.degree_centrality(S)
#
# # Plot the histogram of degree centrality values
# # degree of centrality = ...
#
# plt.hist(list(dcs.values()))
# plt.yscale('log')
# plt.show()

# %%
graph = nx.from_pandas_edgelist(ride_counts,\
                                         source = 'Start_id', \
                                         target = 'End_id', \
                                         edge_attr = 'counts', \
                                         create_using = nx.Graph())

# %%
graph.nodes
# Out:
# NodeView((30000.0, 30001.0, 30002.0, 30003.0, 30004.0, 30005.0, 30006.0, 30007.0, 30008.0, 30009.0, 30010.0, 30011.0, 30012.0, 30013.0, 30014.0, 30015.0, 30016.0, 30017.0, 30018.0, 30019.0, 30021.0, 30022.0, 30023.0, 30024.0, 30025.0, 30026.0, 30027.0, 30028.0, 30029.0, 30030.0, 30031.0, 30032.0, 30034.0, 30035.0, 30037.0, 30038.0, 30039.0, 30040.0, 30041.0, 30042.0, 30043.0, 30044.0, 30045.0, 30046.0, 30047.0, 30048.0, 30050.0, 30051.0, 30052.0, 30053.0, 30054.0, 30055.0, 30056.0, 30057.0, 30058.0, 30059.0, 30060.0, 30061.0, 30062.0, 30063.0, 30064.0, 30065.0, 30066.0, 30068.0, 30069.0, 30071.0, 30073.0, 30074.0, 30075.0, 30076.0, 30080.0, 30081.0, 30083.0, 30087.0, 30088.0, 30089.0, 30090.0, 30091.0, 30092.0, 30093.0, 30094.0, 30095.0, 30096.0, 30097.0, 30098.0, 30103.0, 30104.0, 30108.0, 30109.0, 30110.0, 30112.0, 30113.0, 30114.0, 30115.0, 30142.0, 30143.0, 30144.0, 30145.0, 30146.0, 30147.0, 30149.0, 30150.0, 30151.0, 30152.0, 30153.0, 30154.0, 30155.0, 30157.0, 30158.0, 30160.0, 30161.0, 30162.0, 30163.0, 30164.0, 30165.0, 30166.0, 30167.0, 30168.0, 30169.0, 30170.0, 30171.0, 30172.0, 30173.0, 30174.0, 30175.0, 30176.0, 30177.0, 30178.0, 30179.0, 30180.0, 30181.0, 30182.0, 30183.0, 30184.0, 30185.0, 30186.0, 30187.0, 30188.0, 30189.0, 30190.0, 30191.0, 30192.0, 30193.0, 30194.0, 30195.0, 30196.0, 30197.0, 30198.0, 30201.0, 30202.0, 30203.0, 30204.0, 30020.0, 30033.0, 30049.0, 30077.0, 30085.0, 30086.0, 30099.0, 30100.0, 30102.0, 30123.0, 30134.0, 30136.0, 30199.0, 30078.0, 30148.0, 30067.0, 30070.0, 30082.0, 30107.0, 30140.0, 30105.0, 30126.0, 30127.0, 30156.0, 30101.0, 30118.0, 30079.0, 30111.0, 30116.0, 30119.0, 30132.0, 30159.0, 30121.0, 30138.0, 30128.0, 30131.0, 30117.0, 30122.0, 30135.0, 30137.0, 30106.0, 30120.0, 30139.0, 30124.0, 30130.0, 30141.0, 30125.0, 30129.0, 30133.0))

# %%
edge = dict(alpha=[])

for u, v, d in graph.edges.data('counts', default = 0):
    edge['alpha'].append(d)
edge['alpha'] = [a / max(edge['alpha']) for a in edge['alpha']]

# %%
np.mean(edge['alpha'])
# Out:
# 0.0046892891801778511

# %%
edge = dict(alpha=[])

for u, v, d in graph.edges.data('counts', default = 0):
    edge['alpha'].append(np.log(d))
edge['alpha'] = [a / max(edge['alpha']) for a in edge['alpha']]

# %%
max(edge['alpha'])
# Out:
# 1.0

# %%
np.mean(edge['alpha'])
# Out:
# 0.20230490309817167

# %%
edge['alpha'].append(np.log(d)*100) # rescale for later alpha normalization
        
    # create values of alpha that are between 0 and 1
edge['alpha'] = [a / max(edge['alpha']) for a in edge['alpha']]

# %%
##### Part 1: simple network visualization ####
###################################################################################################
# extract country and then extra columns

def simple_visualization (station_df, rides_df):
    if (station_df is None) or (rides_df is None):
        print("Data cannot be retrieved and read")
    else:
        # returns a dataframe with the total count of rides from station start and station end
        ride_counts = rides_df.drop(['Start_date', 'Start_name', 'End_date', 'End_name', 'duration', 'account'], axis=1)
        ride_counts['counts'] = 0
        ride_counts = ride_counts.groupby(by=['Start_id', 'End_id'],axis=0, as_index=False)['counts'].count()

        # Counts of total rides from any station start point
        counts = ride_counts.groupby('Start_id', as_index=False).sum().drop('End_id', axis=1)
        
        # Station data, w/total rides merged in
        pos_data = station_df.merge(counts, left_on = 'Terminal', right_on='Start_id').drop(['Ndocks', 'Start_id'], axis=1)

    # Create graph
        graph = nx.from_pandas_edgelist(ride_counts,\
                                         source = 'Start_id', \
                                         target = 'End_id', \
                                         edge_attr = 'counts', \
                                         create_using = nx.Graph())

    # Set up base map
        plt.figure(figsize=(20,20))
        m = Basemap(
                projection='merc',
                llcrnrlon=-93.22,
                llcrnrlat=44.94,
                urcrnrlon=-93.31,
                urcrnrlat=45,
                lat_ts=0,
                resolution='l',
                suppress_ticks=True)

    # import long lat as m attribute
        mx, my = m(pos_data['Longitude'].values, pos_data['Latitude'].values)
        pos = {}
        for count, elem in enumerate (pos_data['Terminal']):
            pos[elem] = (mx[count], my[count])

    # draw nodes and edges and over aly on basemap
        
        nx.draw_networkx_nodes(G = graph, pos = pos, node_list = graph.nodes(), node_color = 'r', alpha = 0.8,
                               node_size = [(counts.counts.values * .33)])
        nx.draw_networkx_edges(G = graph, pos = pos, edge_color='g', width = (np.log(ride_counts['counts'].values) / 2), 
                               alpha=0.2, arrows = False)
        
       
        plt.tight_layout()
        plt.savefig("/home/grimoire/Projects/NiceRide/Visualizations/Networkx/"+str(year)+"_networkx.png")
        plt.show()

# %%
simple_visualization(station_df, rides_df)
# advanced_visualization(airport_df, routes_df)
